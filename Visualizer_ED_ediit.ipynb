# %%
import numpy as np
import pandas as pd
import datetime as dt
from pathlib import Path
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
data_to_load = Path(f"Resources/Queried/MCGbyCEO.csv")

data_df = pd.read_csv(data_to_load)

data_df
# Out:
#     CompanyName   Change  Year       CeoName
# 0        Amazon   0.0000  1997    Jeff Bezos
# 1        Amazon  10.8134  1998    Jeff Bezos
# 2        Amazon   0.5406  1999    Jeff Bezos
# 3        Amazon  -0.7885  2000    Jeff Bezos
# 4        Amazon  -0.2734  2001    Jeff Bezos
# ..          ...      ...   ...           ...
# 102     Netflix   0.1196  2021  Ted Sarandos
# 103     Netflix  -0.5094  2022  Ted Sarandos
# 104     Netflix   0.6239  2023  Ted Sarandos
# 105     Netflix   0.6239  2023   Greg Peters
# 106     Netflix   0.3274  2024   Greg Peters
#
# [107 rows x 4 columns]

# %%
# Change in Market Cap Growth by CEO

data_to_load = Path(f"Resources/Queried/MCGbyCEO.csv")

data_df = pd.read_csv(data_to_load)

data_df


CompanyList = data_df.CompanyName.unique()
for company in CompanyList:

    #Filter down to correct company
    company_data = data_df[(data_df.CompanyName == company)]

    #create list of ceos 
    CeoList = company_data.CeoName.unique()

    #create dictionary of dataframes, each one holding one ceo's tenure
    ceo_dict =dict()
    fig, ax = plt.subplots()
    for name in CeoList:
        ceo_dict[name] = company_data[(company_data.CeoName == name)]
        ax.plot("Year", "Change", data=ceo_dict[name], label = name )
    
    ax.set(xlabel="Year", ylabel="Change in MarketCap", title= f"MarketCap Growth by CEO - {company}")
    ax.legend()

    plt.show

# %%
# Change in Market Cap Growth by CEO

data_to_load = Path(f"Resources/Queried/MCbyCEO.csv")

data_df = pd.read_csv(data_to_load)

data_df


CompanyList = data_df.CompanyName.unique()

for company in CompanyList:

    

    #Filter down to correct company
    company_data = data_df[(data_df.CompanyName == company)]

    #create list of ceos 
    CeoList = company_data.CeoName.unique()

    #create dictionary of dataframes, each one holding one ceo's tenure
    ceo_dict =dict()
    fig, ax = plt.subplots()
    for name in CeoList:
        ceo_dict[name] = company_data[(company_data.CeoName == name)]
        ax.plot("Year", "MarketCap(Billions)", data=ceo_dict[name], label = name )
    
    ax.set(xlabel="Year", ylabel="MarketCap", title= f"MarketCap by CEO - {company}")
    ax.legend()

    plt.show

# %%
# Change in Market Cap by Company

data_to_load = Path(f"Resources/Queried/MCbyCEO.csv")

data_df = pd.read_csv(data_to_load)

data_df


CompanyList = data_df.CompanyName.unique()
company_dict =dict()
fig, ax = plt.subplots()

for company in CompanyList:
    
    #create dictionary of dataframes, each one holding one ceo's tenure
    company_dict[company] = data_df[(data_df.CompanyName == company)]
    ax.plot("Year", "MarketCap(Billions)", data =company_dict[company], label = company )
    
    

ax.set(xlabel="Year", ylabel="MarketCap", title= f"MarketCap by Company")

ax.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Change in Stock by Company

data_to_load = Path(f"Resources/Queried/StockbyCEOSmall.csv")

data_df = pd.read_csv(data_to_load)
data_df["Date"]= pd.to_datetime(data_df["Date"])

data_df


CompanyList = data_df.CompanyName.unique()
company_dict =dict()
fig, ax = plt.subplots()

for company in CompanyList:
    
    #create dictionary of dataframes
    company_dict[company] = data_df[(data_df.CompanyName == company)]
    ax.plot("Date", "Close", data =company_dict[company], label = company )
    
    

ax.set(xlabel="Year", ylabel="Close", title= f"Stock by Company")

ax.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 871 entries, 0 to 870
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CompanyName  871 non-null    object
#  1   year_stock   871 non-null    int64
#  2   Close        871 non-null    float64
#  3   Volume       871 non-null    int64
#  4   Date         871 non-null    object
#  5   CeoName      871 non-null    object
#  6   extract      871 non-null    int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 47.8+ KB

# %%
data_df["Date"]= pd.to_datetime(data_df["Date"])

# %%
# Change in Stock by Company

data_to_load = Path(f"Resources/Queried/StockbyCEOSmall (1).csv")

data_df = pd.read_csv(data_to_load)
data_df["Date"]= pd.to_datetime(data_df["Date"])

data_df


CompanyList = data_df.CompanyName.unique()
company_dict =dict()
fig, ax = plt.subplots()

for company in CompanyList:
    
    #create dictionary of dataframes
    company_dict[company] = data_df[(data_df.CompanyName == company)]
    ax.plot("Date", "Close", data =company_dict[company], label = company )
    
    

ax.set(xlabel="Year", ylabel="Close", title= f"Stock by Company")

ax.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
